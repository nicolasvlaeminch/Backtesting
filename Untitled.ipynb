# %%
from backtesting import Backtest, Strategy
import talib
import pandas as pd

#Descargamos los datos

data = pd.read_csv("BTC-Hourly.csv")
data["Date"] = pd.DatetimeIndex(data["Date"])
data = data.set_index("Date")

close = data.Close.values

data

class EMAcross(Strategy):
    def init(self):
        self.ema30 = self.I(talib.EMA,self.data.Close,30)
        self.ema75 = self.I(talib.EMA,self.data.Close,75)
        self.ema100 = self.I(talib.EMA,self.data.Close,100)
        self.ema200 = self.I(talib.EMA,self.data.Close,200)
        self.pasoUno = 0
        self.pasoDos = 0
        self.pasoTres = 0

    def should_skip_day(self):
        # Obtén el día de la semana (0 = lunes, 6 = domingo)
        weekday = self.data.index[-1].weekday()
        # Devuelve True si es sábado (5) o domingo (6), de lo contrario, False
        return weekday in [5, 6]

    def next(self):
        price = self.data.Close[-1]

        if self.should_skip_day():
            return

        if self.ema30[-1] > self.ema75[-1] and self.ema30[-1] < self.ema100[-1] and not self.position.is_long:
            self.pasoUno = 1

        if self.pasoUno > 0 and self.ema30[-1] > self.ema100[-1] and self.ema75[-1] > self.ema100[-1]:
            if self.ema30[-1] > self.ema75[-1]:
                self.pasoDos = 1
            else:
                self.pasoUno = 0
                self.pasoDos = 0

        if self.pasoUno > 0 and self.pasoDos > 0 and price < self.ema100[-1] and self.ema100[-1] > self.ema200[-1]:
            self.pasoTres = 1

        if self.pasoTres > 0 and price < self.ema200[-1]:
            self.pasoUno = 0
            self.pasoDos = 0
            self.pasoTres = 0

        if self.pasoTres > 0 and price > self.ema75[-1]:
            self.buy(limit = None, sl = price*0.992, tp = price*1.04)
            self.pasoUno = 0
            self.pasoDos = 0
            self.pasoTres = 0

bt = Backtest(data,EMAcross,cash = 100000, exclusive_orders=True)

#Ejecutamos el backtest
stats = bt.run()

#Vamos los resultados del backtest
print(stats)

bt.plot(resample='1H')
# Out:
# C:\Users\Naiki\AppData\Local\Temp\ipykernel_10404\1743485932.py:61: UserWarning: Data index is not sorted in ascending order. Sorting.
#   bt = Backtest(data,EMAcross,cash = 100000, exclusive_orders=True)
# Start                     2018-05-15 06:00:00
# End                       2022-03-01 00:00:00
# Duration                   1385 days 18:00:00
# Exposure Time [%]                    0.724616
# Equity Final [$]                   96868.4464
# Equity Peak [$]                  101324.64448
# Return [%]                          -3.131554
# Buy & Hold Return [%]              395.507603
# Return (Ann.) [%]                   -0.833777
# Volatility (Ann.) [%]                4.064459
# Sharpe Ratio                              0.0
# Sortino Ratio                             0.0
# Calmar Ratio                              0.0
# Max. Drawdown [%]                    -5.32859
# Avg. Drawdown [%]                   -3.461133
# Max. Drawdown Duration      935 days 01:00:00
# Avg. Drawdown Duration      444 days 12:00:00
# # Trades                                   22
# Win Rate [%]                        13.636364
# Best Trade [%]                            4.0
# Worst Trade [%]                     -0.911736
# Avg. Trade [%]                      -0.165072
# Max. Trade Duration           3 days 07:00:00
# Avg. Trade Duration           0 days 10:00:00
# Profit Factor                         0.78196
# Expectancy [%]                      -0.151797
# SQN                                 -0.436838
# _strategy                            EMAcross
# _equity_curve                             ...
# _trades                       Size  EntryB...
# dtype: object
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 69
#      66 #Vamos los resultados del backtest
#      67 print(stats)
# ---> 69 bt.plot(resample='1H')
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\backtesting\backtesting.py:1592, in Backtest.plot(self, results, filename, plot_width, plot_equity, plot_return, plot_pl, plot_volume, plot_drawdown, smooth_equity, relative_equity, superimpose, resample, reverse_indicators, show_legend, open_browser)
#    1589         raise RuntimeError('First issue `backtest.run()` to obtain results.')
#    1590     results = self._results
# -> 1592 return plot(
#    1593     results=results,
#    1594     df=self._data,
#    1595     indicators=results._strategy._indicators,
#    1596     filename=filename,
#    1597     plot_width=plot_width,
#    1598     plot_equity=plot_equity,
#    1599     plot_return=plot_return,
#    1600     plot_pl=plot_pl,
#    1601     plot_volume=plot_volume,
#    1602     plot_drawdown=plot_drawdown,
#    1603     smooth_equity=smooth_equity,
#    1604     relative_equity=relative_equity,
#    1605     superimpose=superimpose,
#    1606     resample=resample,
#    1607     reverse_indicators=reverse_indicators,
#    1608     show_legend=show_legend,
#    1609     open_browser=open_browser)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\backtesting\_plotting.py:203, in plot(results, df, indicators, filename, plot_width, plot_equity, plot_return, plot_pl, plot_volume, plot_drawdown, smooth_equity, relative_equity, superimpose, resample, reverse_indicators, show_legend, open_browser)
#     201 # Limit data to max_candles
#     202 if is_datetime_index:
# --> 203     df, indicators, equity_data, trades = _maybe_resample_data(
#     204         resample, df, indicators, equity_data, trades)
#     206 df.index.name = None  # Provides source name @index
#     207 df['datetime'] = df.index  # Save original, maybe datetime index
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\backtesting\_plotting.py:153, in _maybe_resample_data(resample_rule, df, indicators, equity_data, trades)
#     150     return f
#     152 if len(trades):  # Avoid pandas "resampling on Int64 index" error
# --> 153     trades = trades.assign(count=1).resample(freq, on='ExitTime', label='right').agg(dict(
#     154         TRADES_AGG,
#     155         ReturnPct=_weighted_returns,
#     156         count='sum',
#     157         EntryBar=_group_trades('EntryTime'),
#     158         ExitBar=_group_trades('ExitTime'),
#     159     )).dropna()
#     161 return df, indicators, equity_data, trades
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\resample.py:338, in Resampler.aggregate(self, func, *args, **kwargs)
#     330 @doc(
#     331     _shared_docs["aggregate"],
#     332     see_also=_agg_see_also_doc,
#    (...)
#     336 )
#     337 def aggregate(self, func=None, *args, **kwargs):
# --> 338     result = ResamplerWindowApply(self, func, args=args, kwargs=kwargs).agg()
#     339     if result is None:
#     340         how = func
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\apply.py:175, in Apply.agg(self)
#     172     return self.apply_str()
#     174 if is_dict_like(func):
# --> 175     return self.agg_dict_like()
#     176 elif is_list_like(func):
#     177     # we require a list, but not a 'str'
#     178     return self.agg_list_like()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\apply.py:406, in Apply.agg_dict_like(self)
#     398 def agg_dict_like(self) -> DataFrame | Series:
#     399     """
#     400     Compute aggregation in the case of a dict-like argument.
#     401
#    (...)
#     404     Result of aggregation.
#     405     """
# --> 406     return self.agg_or_apply_dict_like(op_name="agg")
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\apply.py:1388, in GroupByApply.agg_or_apply_dict_like(self, op_name)
#    1383     kwargs.update({"engine": engine, "engine_kwargs": engine_kwargs})
#    1385 with com.temp_setattr(
#    1386     obj, "as_index", True, condition=hasattr(obj, "as_index")
#    1387 ):
# -> 1388     result_index, result_data = self.compute_dict_like(
#    1389         op_name, selected_obj, selection, kwargs
#    1390     )
#    1391 result = self.wrap_results_dict_like(selected_obj, result_index, result_data)
#    1392 return result
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\apply.py:479, in Apply.compute_dict_like(self, op_name, selected_obj, selection, kwargs)
#     476         results += key_data
#     477 else:
#     478     # key used for column selection and output
# --> 479     results = [
#     480         getattr(obj._gotitem(key, ndim=1), op_name)(how, **kwargs)
#     481         for key, how in func.items()
#     482     ]
#     483     keys = list(func.keys())
#     485 return keys, results
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\apply.py:480, in <listcomp>(.0)
#     476         results += key_data
#     477 else:
#     478     # key used for column selection and output
#     479     results = [
# --> 480         getattr(obj._gotitem(key, ndim=1), op_name)(how, **kwargs)
#     481         for key, how in func.items()
#     482     ]
#     483     keys = list(func.keys())
#     485 return keys, results
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\groupby\generic.py:289, in SeriesGroupBy.aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     286     return self._python_agg_general(func, *args, **kwargs)
#     288 try:
# --> 289     return self._python_agg_general(func, *args, **kwargs)
#     290 except KeyError:
#     291     # KeyError raised in test_groupby.test_basic is bc the func does
#     292     #  a dictionary lookup on group.name, but group name is not
#     293     #  pinned in _python_agg_general, only in _aggregate_named
#     294     result = self._aggregate_named(func, *args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\groupby\generic.py:322, in SeriesGroupBy._python_agg_general(self, func, *args, **kwargs)
#     319 f = lambda x: func(x, *args, **kwargs)
#     321 obj = self._obj_with_exclusions
# --> 322 result = self.grouper.agg_series(obj, f)
#     323 res = obj._constructor(result, name=obj.name)
#     324 return self._wrap_aggregated_output(res)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\groupby\ops.py:850, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     843 if len(obj) > 0 and not isinstance(obj._values, np.ndarray):
#     844     # we can preserve a little bit more aggressively with EA dtype
#     845     #  because maybe_cast_pointwise_result will do a try/except
#     846     #  with _from_sequence.  NB we are assuming here that _from_sequence
#     847     #  is sufficiently strict that it casts appropriately.
#     848     preserve_dtype = True
# --> 850 result = self._aggregate_series_pure_python(obj, func)
#     852 npvalues = lib.maybe_convert_objects(result, try_float=False)
#     853 if preserve_dtype:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\groupby\ops.py:871, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#     868 splitter = self._get_splitter(obj, axis=0)
#     870 for i, group in enumerate(splitter):
# --> 871     res = func(group)
#     872     res = extract_result(res)
#     874     if not initialized:
#     875         # We only do this validation on the first iteration
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\groupby\generic.py:319, in SeriesGroupBy._python_agg_general.<locals>.<lambda>(x)
#     317     alias = com._builtin_table_alias[func]
#     318     warn_alias_replacement(self, orig_func, alias)
# --> 319 f = lambda x: func(x, *args, **kwargs)
#     321 obj = self._obj_with_exclusions
#     322 result = self.grouper.agg_series(obj, f)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\backtesting\_plotting.py:147, in _maybe_resample_data.<locals>._group_trades.<locals>.f(s, new_index, bars)
#     144 def f(s, new_index=pd.Index(df.index.view(int)), bars=trades[column]):
#     145     if s.size:
#     146         # Via int64 because on pandas recently broken datetime
# --> 147         mean_time = int(bars.loc[s.index].view(int).mean())
#     148         new_bar_idx = new_index.get_loc(mean_time, method='nearest')
#     149         return new_bar_idx
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\series.py:896, in Series.view(self, dtype)
#     893 # self.array instead of self._values so we piggyback on NumpyExtensionArray
#     894 #  implementation
#     895 res_values = self.array.view(dtype)
# --> 896 res_ser = self._constructor(res_values, index=self.index, copy=False)
#     897 if isinstance(res_ser._mgr, SingleBlockManager):
#     898     blk = res_ser._mgr._block
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\series.py:503, in Series.__init__(self, data, index, dtype, name, copy, fastpath)
#     501     index = default_index(len(data))
#     502 elif is_list_like(data):
# --> 503     com.require_length_match(data, index)
#     505 # create/copy the manager
#     506 if isinstance(data, (SingleBlockManager, SingleArrayManager)):
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\common.py:561, in require_length_match(data, index)
#     557 """
#     558 Check the length of data matches the length of the index.
#     559 """
#     560 if len(data) != len(index):
# --> 561     raise ValueError(
#     562         "Length of values "
#     563         f"({len(data)}) "
#     564         "does not match length of index "
#     565         f"({len(index)})"
#     566     )
#
# ValueError: Length of values (2) does not match length of index (1)
